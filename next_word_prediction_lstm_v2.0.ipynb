# %% [markdown]
# # Next Word Prediction using Stacked Bidirectional LSTM + Multi-Head Attention
# ## Language Model trained on Shakespeare's Complete Works
#
# **Architecture:** 3-layer Bidirectional LSTM → Multi-Head Self-Attention (residual) → Dense
# **Corpus:** Shakespeare Complete Works (~900K tokens, 15K vocab)
# **Framework:** TensorFlow 2.x / Keras
#
# ---
# ### Table of Contents
# 1. Environment Setup & Imports
# 2. Data Acquisition & Corpus Loading
# 3. Text Preprocessing & Tokenisation
# 4. Sequence Generation & Dataset Construction
# 5. Model Architecture (Bi-LSTM + MHA)
# 6. Training with Callbacks
# 7. Training Visualisations
# 8. Test Set Evaluation
# 9. Text Generation / Inference Demo
# 10. Analysis & Conclusion

# %% [markdown]
# ## 1 - Environment Setup & Imports

# %%
# ─── Standard library ───────────────────────────────────────────────────────
import os
import re
import json
import random
import string
import pickle
import requests
import warnings
warnings.filterwarnings('ignore')

# ─── Numerical / Data ────────────────────────────────────────────────────────
import numpy as np
import pandas as pd

# ─── Visualisation ───────────────────────────────────────────────────────────
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from matplotlib.ticker import MaxNLocator
# https://matplotlib.org/stable/users/explain/customizing.html
plt.rcParams.update({
    'figure.facecolor': 'white',
    'axes.facecolor':   '#F8F7F4',
    'axes.grid':        True,
    'grid.alpha':       0.4,
    'font.family':      'DejaVu Sans',
    'axes.spines.top':  False,
    'axes.spines.right':False,
})
PALETTE = {'train': '#534AB7', 'val': '#D85A30', 'test': '#1D9E75'}

# ─── NLP ─────────────────────────────────────────────────────────────────────
import nltk
# https://www.gutenberg.org/
nltk.download('gutenberg', quiet=True)
nltk.download('punkt',     quiet=True)
from nltk.corpus import gutenberg

# ─── ML / Deep Learning ──────────────────────────────────────────────────────
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers, callbacks as keras_callbacks
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import top_k_accuracy_score

# ─── Reproducibility ─────────────────────────────────────────────────────────
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'


print(f'TensorFlow version: {tf.__version__}')
print(f'GPU available: {bool(tf.config.list_physical_devices("GPU"))}  (CPU training will be used)')
print('All imports successful.')
# Out:
# TensorFlow version: 2.21.0
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# GPU available: False  (CPU training will be used)
# All imports successful.

# %% [markdown]
# ---
# ## 2 — Data Acquisition & Corpus Loading

# %%
# ─── Load Shakespeare plays from NLTK Gutenberg corpus ───────────────────────
# https://www.gutenberg.org/cache/epub/100/pg100.txt
url = "https://www.gutenberg.org/cache/epub/100/pg100.txt"

text = requests.get(url).text

with open("complete_shakespeare.txt", "w", encoding="utf-8") as f:
    f.write(text)

CORPUS_RAW = text


print(f'\nCombined corpus length : {len(CORPUS_RAW):,} characters')
print('First 500 characters:\n', CORPUS_RAW[:500])
# Out:
# Combined corpus length : 5,575,099 characters
# First 500 characters:
#  The Project Gutenberg eBook of The Complete Works of William Shakespeare
#
# This eBook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this eBook or online
# at www.gutenberg.org. If you are not located in the United States,
# you will have to check the laws of the country where you are locat

# %% [markdown]
# ---
# ## 3 — Text Preprocessing & Tokenisation

# %%
# ─── Preprocessing function ──────────────────────────────────────────────────
def clean_text(text: str) -> str:
    """Normalise Shakespeare text for language modelling."""
    # 1. Lowercase everything
    text = text.lower()
    # 2. Remove content inside square brackets (stage directions)
    text = re.sub(r'\[.*?\]', ' ', text)
    # 3. Remove line numbers that appear at start of lines (e.g. "  1  ")
    text = re.sub(r'^\s*\d+\s*$', '', text, flags=re.MULTILINE)
    # 4. Keep only letters, basic punctuation, and spaces
    text = re.sub(r"[^a-z\s.,!?;:'\-]", ' ', text)
    # 5. Add spaces around punctuation so they become separate tokens
    #    This makes punctuation predictable (huge accuracy boost)
    text = re.sub(r"([.,!?;:])", r" \1 ", text)
    # 6. Collapse multiple whitespace into single space
    text = re.sub(r'\s+', ' ', text).strip()
    return text

CORPUS_CLEAN = clean_text(CORPUS_RAW)

# ─── Keras Tokenizer — builds word → integer mapping ─────────────────────────
# IMPORTANT: No filters on punctuation — we WANT .,!?;: as tokens
# Punctuation is highly predictable and boosts accuracy significantly
tokenizer = Tokenizer(
    num_words=5000,        # Cap vocab at top 5000 words (reduces output space)
    oov_token='<OOV>',
    lower=True,
    filters='"#$%&()*+-/<=>@[\\]^_`{|}~\t\n'  # Keep .,!?;:' as valid tokens
)
tokenizer.fit_on_texts([CORPUS_CLEAN])

# ─── Vocabulary statistics ────────────────────────────────────────────────────
word_index  = tokenizer.word_index        # word → int
index_word  = tokenizer.index_word        # int → word
# With num_words=5000, effective vocab is min(len(word_index)+1, 5000)
VOCAB_SIZE  = min(len(word_index) + 1, 5000)
TOTAL_WORDS = sum(tokenizer.word_counts.values())

print('── Preprocessing ─────────────────────────────────────────')
print(f'  Raw corpus length   : {len(CORPUS_RAW):,} chars')
print(f'  Cleaned length      : {len(CORPUS_CLEAN):,} chars')
print(f'  Total word tokens   : {TOTAL_WORDS:,}')
print(f'  Full vocabulary     : {len(word_index)+1:,}')
print(f'  Effective vocab     : {VOCAB_SIZE:,}   (capped by num_words)')
print(f'  OOV token idx       : {word_index["<OOV>"]}  (<OOV>)')
print(f'\nSample cleaned text (first 300 chars):\n', CORPUS_CLEAN[:300])
print(f'\nSample word index entries (first 15):', list(tokenizer.word_index.items())[:15])
# Out:
# ── Preprocessing ─────────────────────────────────────────
#   Raw corpus length   : 5,575,099 chars
#   Cleaned length      : 5,437,874 chars
#   Total word tokens   : 1,198,742
#   Full vocabulary     : 24,611
#   Effective vocab     : 5,000   (capped by num_words)
#   OOV token idx       : 1  (<OOV>)
#
# Sample cleaned text (first 300 chars):
#  the project gutenberg ebook of the complete works of william shakespeare this ebook is for the use of anyone anywhere in the united states and most other parts of the world at no cost and with almost no restrictions whatsoever . you may copy it , give it away or re-use it under the terms of the proj
#
# Sample word index entries (first 15): [('<OOV>', 1), (',', 2), ('.', 3), ('the', 4), ('and', 5), ('i', 6), ('to', 7), ('of', 8), ('a', 9), ('you', 10), ('my', 11), (';', 12), ('in', 13), ('that', 14), ('?', 15)]

# %% [markdown]
# ---
# ## Cell 4 — Sequence Generation & Dataset Construction

# %%
# ─── Hyperparameters for sequence construction ────────────────────────────────
SEQ_LEN = 30       # Context window length
STRIDE   = 1       # Stride=1 is fine now since we split by contiguous blocks

# ─── Convert entire corpus to a flat list of integer token IDs ───────────────
token_ids = tokenizer.texts_to_sequences([CORPUS_CLEAN])[0]

# ─── CONTIGUOUS SPLIT: standard for language modelling ────────────────────────
# Split the token sequence into contiguous blocks BEFORE creating (X, y) pairs.
# This prevents data leakage between train/val/test — no shared n-gram contexts.
# (Used by GPT, BERT pretraining, Karpathy's char-RNN, etc.)
n_tokens = len(token_ids)
train_end = int(n_tokens * 0.80)
val_end   = int(n_tokens * 0.90)

train_tokens = token_ids[:train_end]
val_tokens   = token_ids[train_end:val_end]
test_tokens  = token_ids[val_end:]

def make_sequences(tokens, seq_len, stride):
    """Build (X, y) pairs from a contiguous token list."""
    X, y = [], []
    for i in range(0, len(tokens) - seq_len, stride):
        X.append(tokens[i : i + seq_len])
        y.append(tokens[i + seq_len])
    return np.array(X, dtype=np.int32), np.array(y, dtype=np.int32)

X_train, y_train = make_sequences(train_tokens, SEQ_LEN, STRIDE)
X_val,   y_val   = make_sequences(val_tokens,   SEQ_LEN, STRIDE)
X_test,  y_test  = make_sequences(test_tokens,  SEQ_LEN, STRIDE)

# Keep copies for top-k evaluation
y_test_int = y_test.copy()

print('── Dataset construction ──────────────────────────────────')
print(f'  Sequence length     : {SEQ_LEN}  tokens (input)')
print(f'  Sliding stride      : {STRIDE}   tokens')
print(f'  Total corpus tokens : {n_tokens:,}')
print(f'\n── Contiguous split (no data leakage) ───────────────────')
print(f'  Train tokens        : {len(train_tokens):,}  (80%)')
print(f'  Val tokens          : {len(val_tokens):,}   (10%)')
print(f'  Test tokens         : {len(test_tokens):,}   (10%)')
print(f'\n── Sequences generated ──────────────────────────────────')
print(f'  Training samples    : {len(X_train):,}')
print(f'  Validation samples  : {len(X_val):,}')
print(f'  Test samples        : {len(X_test):,}')
print(f'\n  X_train shape       : {X_train.shape}')
print(f'  y_train shape       : {y_train.shape}   (sparse integer labels)')
print(f'\nMemory footprint (training X): {X_train.nbytes / 1e6:.1f} MB')
# Out:
# ── Dataset construction ──────────────────────────────────
#   Sequence length     : 30  tokens (input)
#   Sliding stride      : 1   tokens
#   Total corpus tokens : 1,198,742
#
# ── Contiguous split (no data leakage) ───────────────────
#   Train tokens        : 958,993  (80%)
#   Val tokens          : 119,874   (10%)
#   Test tokens         : 119,875   (10%)
#
# ── Sequences generated ──────────────────────────────────
#   Training samples    : 958,963
#   Validation samples  : 119,844
#   Test samples        : 119,845
#
#   X_train shape       : (958963, 30)
#   y_train shape       : (958963,)   (sparse integer labels)
#
# Memory footprint (training X): 115.1 MB

# %% [markdown]
# ---
# ## Cell 5 — Model Architecture: Stacked Bi-LSTM + Multi-Head Attention

# %%
# https://www.geeksforgeeks.org/deep-learning/deep-learning-introduction-to-long-short-term-memory/
# https://www.tensorflow.org/text/tutorials/text_generation
# https://karpathy.github.io/2015/05/21/rnn-effectiveness/

# ─── Training hyperparameters ─────────────────────────────────────────────────
EMBED_DIM   = 128   # Embedding dimension
LSTM1_UNITS = 128   # 1st Bi-LSTM hidden units
LSTM2_UNITS = 64    # 2nd Bi-LSTM hidden units (reduced — 2 layers is enough)
MHA_HEADS   = 4     # Multi-head attention: number of heads
MHA_KEY_DIM = 32    # Key dimensionality per head
DENSE_UNITS = 256   # Penultimate dense layer
DROP_EMB    = 0.20  # Light dropout — let the model learn
DROP_LSTM   = 0.20  # Light dropout between LSTM stacks
DROP_DENSE  = 0.30  # Moderate before output
L2_REG      = 5e-6  # Light L2 regularization

# ─── Build model using Keras Functional API ───────────────────────────────────
# https://keras.io/api/models/model/
def build_model(vocab_size: int, seq_len: int) -> keras.Model:
    """
    Stacked Bidirectional LSTM + Multi-Head Self-Attention language model.
    
    Architecture (simplified to 2 LSTM layers for small corpus):
      Input → Embedding + SpatialDropout
      → BiLSTM-128 (return_seq) → BatchNorm → Dropout
      → BiLSTM-64  (return_seq)
      → MultiHeadAttention (residual + LayerNorm)
      → GlobalAveragePooling
      → Dense-256 (ReLU) → Dropout
      → Dense-vocab (Softmax)
    """
    
    inputs = keras.Input(shape=(seq_len,), name='token_ids')

    # ── Embedding layer ───────────────────────────────────────────────────────
    x = layers.Embedding(
        input_dim=vocab_size,
        output_dim=EMBED_DIM,
        embeddings_regularizer=regularizers.l2(L2_REG),
        name='embedding'
    )(inputs)

    x = layers.SpatialDropout1D(DROP_EMB, name='spatial_dropout')(x)

    # ── Bi-LSTM layer 1 ──────────────────────────────────────────────────────
    x = layers.Bidirectional(
        layers.LSTM(
            LSTM1_UNITS,
            return_sequences=True,
            kernel_regularizer=regularizers.l2(L2_REG),
            recurrent_dropout=0.0,
            name='lstm_1'
        ),
        name='bidirectional'
    )(x)    

    x = layers.BatchNormalization(momentum=0.9, name='bn_1')(x)
    x = layers.Dropout(DROP_LSTM, name='drop_1')(x)

    # ── Bi-LSTM layer 2 ──────────────────────────────────────────────────────
    lstm_out = layers.Bidirectional(
        layers.LSTM(
            LSTM2_UNITS,
            return_sequences=True,
            kernel_regularizer=regularizers.l2(L2_REG),
            name='lstm_2'
        ),
        name='bidirectional_1'
    )(x)

    # ── Multi-Head Self-Attention ─────────────────────────────────────────────
    mha_out = layers.MultiHeadAttention(
        num_heads=MHA_HEADS,
        key_dim=MHA_KEY_DIM,
        dropout=0.1,
        name='multi_head_attention'
    )(lstm_out, lstm_out)

    # ── Residual connection ───────────────────────────────────────────────────
    x = layers.Add(name='residual_add')([lstm_out, mha_out])
    x = layers.LayerNormalization(epsilon=1e-6, name='layer_norm')(x)

    # ── Pool over sequence dimension ──────────────────────────────────────────
    x = layers.GlobalAveragePooling1D(name='gap')(x)

    # ── Dense classification head ─────────────────────────────────────────────
    x = layers.Dense(
        DENSE_UNITS,
        activation='relu',
        kernel_regularizer=regularizers.l2(L2_REG),
        name='dense_hidden'
    )(x)
    x = layers.Dropout(DROP_DENSE, name='drop_dense')(x)

    # ── Output layer ──────────────────────────────────────────────────────────
    outputs = layers.Dense(
        vocab_size,
        activation='softmax',
        name='output_softmax'
    )(x)

    model = keras.Model(inputs, outputs, name='NextWordPredictor_BiLSTM_MHA')
    return model

# Build and display the model
model = build_model(VOCAB_SIZE, SEQ_LEN)
model.summary()
# Out:
# Model: "NextWordPredictor_BiLSTM_MHA"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ token_ids           │ (None, 30)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, 30, 128)   │    640,000 │ token_ids[0][0]   │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout     │ (None, 30, 128)   │          0 │ embedding[0][0]   │
# │ (SpatialDropout1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional       │ (None, 30, 256)   │    263,168 │ spatial_dropout[… │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_1                │ (None, 30, 256)   │      1,024 │ bidirectional[0]… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ drop_1 (Dropout)    │ (None, 30, 256)   │          0 │ bn_1[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_1     │ (None, 30, 128)   │    164,352 │ drop_1[0][0]      │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 30, 128)   │     66,048 │ bidirectional_1[… │
# │ (MultiHeadAttentio… │                   │            │ bidirectional_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ residual_add (Add)  │ (None, 30, 128)   │          0 │ bidirectional_1[… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_norm          │ (None, 30, 128)   │        256 │ residual_add[0][… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gap                 │ (None, 128)       │          0 │ layer_norm[0][0]  │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_hidden        │ (None, 256)       │     33,024 │ gap[0][0]         │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ drop_dense          │ (None, 256)       │          0 │ dense_hidden[0][… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output_softmax      │ (None, 5000)      │  1,285,000 │ drop_dense[0][0]  │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,452,872 (9.36 MB)
#  Trainable params: 2,452,360 (9.36 MB)
#  Non-trainable params: 512 (2.00 KB)

# %% [markdown]
# ---
# ## Cell 6 — Custom Perplexity Metric & Model Compilation

# %%
# ─── Custom Perplexity metric ─────────────────────────────────────────────────
# Perplexity = exp(cross-entropy loss); lower is better
# A random baseline over vocab_size words → perplexity ≈ vocab_size
# https://huggingface.co/docs/transformers/en/perplexity

class Perplexity(keras.metrics.Metric):
    """Computes word-level perplexity = exp(cross-entropy)."""
    def __init__(self, name='perplexity', **kwargs):
        super().__init__(name=name, **kwargs)
        self.cross_entropy = keras.metrics.Mean()

    def update_state(self, y_true, y_pred, sample_weight=None):
        ce = keras.losses.sparse_categorical_crossentropy(y_true, y_pred)
        self.cross_entropy.update_state(ce, sample_weight)

    def result(self):
        return tf.exp(self.cross_entropy.result())

    def reset_state(self):
        self.cross_entropy.reset_state()

# ─── Compile ──────────────────────────────────────────────────────────────────
LEARNING_RATE = 0.001  # Back to standard Adam LR — model is smaller now

optimizer = keras.optimizers.Adam(
    learning_rate=LEARNING_RATE,
    clipnorm=1.0
)

# Using SparseCategoricalCrossentropy — works directly with integer labels
loss_fn = keras.losses.SparseCategoricalCrossentropy()

model.compile(
    optimizer=optimizer,
    loss=loss_fn,
    metrics=['accuracy', Perplexity()]
)

print('Model compiled successfully.')
print(f'Optimizer  : Adam  (lr={LEARNING_RATE}, clipnorm=1.0)')
print(f'Loss       : sparse_categorical_crossentropy')
print(f'Metrics    : [\'accuracy\', \'perplexity\']')
# Out:
# Model compiled successfully.
# Optimizer  : Adam  (lr=0.001, clipnorm=1.0)
# Loss       : sparse_categorical_crossentropy
# Metrics    : ['accuracy', 'perplexity']

# %% [markdown]
# ---
# ## Cell 7 — Callbacks & Training

# %%
# ─── Callback definitions ─────────────────────────────────────────────────────
EPOCHS      = 50      # More room to train
BATCH_SIZE  = 128      # Moderate batch size
CKPT_PATH   = 'best_model.keras'

# 1. EarlyStopping: halt training when validation loss stops improving
early_stop = keras_callbacks.EarlyStopping(
    monitor='val_loss',
    patience=15,               # Increased — give model more time to converge
    restore_best_weights=True,
    verbose=1
)

# 2. ReduceLROnPlateau: halve learning rate when val_loss stalls
reduce_lr = keras_callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-6,
    verbose=1
)

# 3. ModelCheckpoint: save best model weights to disk
checkpoint = keras_callbacks.ModelCheckpoint(
    filepath=CKPT_PATH,
    monitor='val_loss',
    save_best_only=True,
    verbose=0
)

# 4. CSVLogger: persist training history to CSV for later analysis
csv_logger = keras_callbacks.CSVLogger('training_log.csv', append=False)

# ─── Train the model ──────────────────────────────────────────────────────────
print('── Training configuration ────────────────────────────────')
print(f'  Epochs (max)        : {EPOCHS}')
print(f'  Batch size          : {BATCH_SIZE}')
print(f'  Steps per epoch     : {len(X_train) // BATCH_SIZE}')
print(f'  Early stop patience : 15 epochs')
print(f'  LR reduction        : ×0.5 if val_loss plateaus for 5 epochs')
print(f'  Checkpoint path     : {CKPT_PATH}')
print()

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=[early_stop, reduce_lr, checkpoint, csv_logger],
    verbose=1
)

print(f'\nTraining complete.')
# Out:
# ── Training configuration ────────────────────────────────
#   Epochs (max)        : 50
#   Batch size          : 128
#   Steps per epoch     : 7491
#   Early stop patience : 15 epochs
#   LR reduction        : ×0.5 if val_loss plateaus for 5 epochs
#   Checkpoint path     : best_model.keras
#
# Epoch 1/50
# 7492/7492 ━━━━━━━━━━━━━━━━━━━━ 528s 70ms/step - accuracy: 0.1750 - loss: 4.9243 - perplexity: 134.3150 - val_accuracy: 0.1752 - val_loss: 5.1851 - val_perplexity: 173.4576 - learning_rate: 0.0010
# Epoch 2/50
# 7492/7492 ━━━━━━━━━━━━━━━━━━━━ 512s 68ms/step - accuracy: 0.1910 - loss: 4.7427 - perplexity: 110.9714 - val_accuracy: 0.1833 - val_loss: 5.1365 - val_perplexity: 163.8954 - learning_rate: 0.0010
# Epoch 3/50
# 7492/7492 ━━━━━━━━━━━━━━━━━━━━ 510s 68ms/step - accuracy: 0.1980 - loss: 4.6504 - perplexity: 100.4697 - val_accuracy: 0.1880 - val_loss: 5.1157 - val_perplexity: 159.5141 - learning_rate: 0.0010
# Epoch 4/50
# 7492/7492 ━━━━━━━━━━━━━━━━━━━━ 521s 69ms/step - accuracy: 0.2029 - loss: 4.5912 - perplexity: 94.1599 - val_accuracy: 0.1918 - val_loss: 5.1097 - val_perplexity: 157.7527 - learning_rate: 0.0010
# Epoch 5/50
# 7492/7492 ━━━━━━━━━━━━━━━━━━━━ 528s 70ms/step - accuracy: 0.2058 - loss: 4.5467 - perplexity: 89.6369 - val_accuracy: 0.1944 - val_loss: 5.0794 - val_perplexity: 152.3851 - learning_rate: 0.0010
# Epoch 6/50
# 7492/7492 ━━━━━━━━━━━━━━━━━━━━ 526s 70ms/step - accuracy: 0.2083 - loss: 4.5111 - perplexity: 86.1388 - val_accuracy: 0.1953 - val_loss: 5.1037 - val_perplexity: 155.5129 - learning_rate: 0.0010
# Epoch 7/50
# 7492/7492 ━━━━━━━━━━━━━━━━━━━━ 521s 70ms/step - accuracy: 0.2111 - loss: 4.4814 - perplexity: 83.2966 - val_accuracy: 0.2012 - val_loss: 5.0621 - val_perplexity: 148.5942 - learning_rate: 0.0010
# Epoch 8/50
# 7492/7492 ━━━━━━━━━━━━━━━━━━━━ 481s 64ms/step - accuracy: 0.2129 - loss: 4.4549 - perplexity: 80.8283 - val_accuracy: 0.1989 - val_loss: 5.0786 - val_perplexity: 150.5922 - learning_rate: 0.0010
# Epoch 9/50
# 7492/7492 ━━━━━━━━━━━━━━━━━━━━ 470s 63ms/step - accuracy: 0.2145 - loss: 4.4323 - perplexity: 78.7830 - val_accuracy: 0.2025 - val_loss: 5.0674 - val_perplexity: 148.4839 - learning_rate: 0.0010
# Epoch 10/50
# 7492/7492 ━━━━━━━━━━━━━━━━━━━━ 473s 63ms/step - accuracy: 0.2158 - loss: 4.4135 - perplexity: 77.1008 - val_accuracy: 0.1999 - val_loss: 5.0768 - val_perplexity: 149.4774 - learning_rate: 0.0010
# Epoch 11/50
# 7492/7492 ━━━━━━━━━━━━━━━━━━━━ 474s 63ms/step - accuracy: 0.2172 - loss: 4.3974 - perplexity: 75.6581 - val_accuracy: 0.2039 - val_loss: 5.0565 - val_perplexity: 146.0839 - learning_rate: 0.0010
# Epoch 12/50
# 7492/7492 ━━━━━━━━━━━━━━━━━━━━ 478s 64ms/step - accuracy: 0.2182 - loss: 4.3825 - perplexity: 74.3686 - val_accuracy: 0.2007 - val_loss: 5.0751 - val_perplexity: 148.4996 - learning_rate: 0.0010
# Epoch 13/50
# 7492/7492 ━━━━━━━━━━━━━━━━━━━━ 534s 71ms/step - accuracy: 0.2195 - loss: 4.3687 - perplexity: 73.1833 - val_accuracy: 0.2010 - val_loss: 5.0844 - val_perplexity: 149.5529 - learning_rate: 0.0010
# Epoch 14/50
# 7492/7492 ━━━━━━━━━━━━━━━━━━━━ 558s 74ms/step - accuracy: 0.2205 - loss: 4.3580 - perplexity: 72.2515 - val_accuracy: 0.2028 - val_loss: 5.0931 - val_perplexity: 150.5594 - learning_rate: 0.0010
# Epoch 15/50
# 7492/7492 ━━━━━━━━━━━━━━━━━━━━ 589s 79ms/step - accuracy: 0.2213 - loss: 4.3475 - perplexity: 71.3604 - val_accuracy: 0.2051 - val_loss: 5.0902 - val_perplexity: 149.8372 - learning_rate: 0.0010
# Epoch 16/50
# 7492/7492 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.2221 - loss: 4.3385 - perplexity: 70.6271
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 7492/7492 ━━━━━━━━━━━━━━━━━━━━ 588s 79ms/step - accuracy: 0.2227 - loss: 4.3383 - perplexity: 70.5794 - val_accuracy: 0.2060 - val_loss: 5.0857 - val_perplexity: 148.8965 - learning_rate: 0.0010
# Epoch 17/50
# 7492/7492 ━━━━━━━━━━━━━━━━━━━━ 603s 80ms/step - accuracy: 0.2284 - loss: 4.2762 - perplexity: 66.4368 - val_accuracy: 0.2077 - val_loss: 5.1125 - val_perplexity: 153.5903 - learning_rate: 5.0000e-04
# Epoch 18/50
# 7492/7492 ━━━━━━━━━━━━━━━━━━━━ 591s 79ms/step - accuracy: 0.2304 - loss: 4.2541 - perplexity: 65.1744 - val_accuracy: 0.2092 - val_loss: 5.1002 - val_perplexity: 152.0087 - learning_rate: 5.0000e-04
# Epoch 19/50
# 7492/7492 ━━━━━━━━━━━━━━━━━━━━ 595s 79ms/step - accuracy: 0.2310 - loss: 4.2407 - perplexity: 64.4012 - val_accuracy: 0.2058 - val_loss: 5.0974 - val_perplexity: 151.7517 - learning_rate: 5.0000e-04
# Epoch 20/50
# 7492/7492 ━━━━━━━━━━━━━━━━━━━━ 602s 80ms/step - accuracy: 0.2317 - loss: 4.2316 - perplexity: 63.8648 - val_accuracy: 0.2075 - val_loss: 5.1031 - val_perplexity: 152.6974 - learning_rate: 5.0000e-04
# Epoch 21/50
# 7492/7492 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.2317 - loss: 4.2251 - perplexity: 63.4672
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 7492/7492 ━━━━━━━━━━━━━━━━━━━━ 592s 79ms/step - accuracy: 0.2327 - loss: 4.2230 - perplexity: 63.3411 - val_accuracy: 0.2084 - val_loss: 5.0990 - val_perplexity: 152.0989 - learning_rate: 5.0000e-04
# Epoch 22/50
# 7492/7492 ━━━━━━━━━━━━━━━━━━━━ 589s 79ms/step - accuracy: 0.2360 - loss: 4.1875 - perplexity: 61.1805 - val_accuracy: 0.2092 - val_loss: 5.1098 - val_perplexity: 153.9508 - learning_rate: 2.5000e-04
# Epoch 23/50
# 7492/7492 ━━━━━━━━━━━━━━━━━━━━ 588s 78ms/step - accuracy: 0.2374 - loss: 4.1758 - perplexity: 60.5381 - val_accuracy: 0.2092 - val_loss: 5.1041 - val_perplexity: 153.2338 - learning_rate: 2.5000e-04
# Epoch 24/50
# 7492/7492 ━━━━━━━━━━━━━━━━━━━━ 589s 79ms/step - accuracy: 0.2378 - loss: 4.1679 - perplexity: 60.1119 - val_accuracy: 0.2094 - val_loss: 5.1111 - val_perplexity: 154.4375 - learning_rate: 2.5000e-04
# Epoch 25/50
# 7492/7492 ━━━━━━━━━━━━━━━━━━━━ 588s 79ms/step - accuracy: 0.2384 - loss: 4.1588 - perplexity: 59.6103 - val_accuracy: 0.2108 - val_loss: 5.1084 - val_perplexity: 154.1131 - learning_rate: 2.5000e-04
# Epoch 26/50
# 7492/7492 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.2378 - loss: 4.1593 - perplexity: 59.6639
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 7492/7492 ━━━━━━━━━━━━━━━━━━━━ 596s 80ms/step - accuracy: 0.2384 - loss: 4.1558 - perplexity: 59.4581 - val_accuracy: 0.2110 - val_loss: 5.1258 - val_perplexity: 156.8892 - learning_rate: 2.5000e-04
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 11.
#
# Training complete.

# %% [markdown]
# ---
# ## Cell 8 — Visualisations

# %%
# ─── Extract training history ─────────────────────────────────────────────────
# history.history is a dict: {'loss': [...], 'val_loss': [...], 'accuracy': [...], ...}
hist = history.history
epochs_ran = range(1, len(hist['loss']) + 1)

print(f'Training ran for {len(hist["loss"])} epochs')
print(f'Best val_loss: {min(hist["val_loss"]):.4f} at epoch {hist["val_loss"].index(min(hist["val_loss"]))+1}')
print(f'Best val_accuracy: {max(hist["val_accuracy"])*100:.2f}%')

# ─── 4-panel training curves ──────────────────────────────────────────────────
fig = plt.figure(figsize=(14, 10), constrained_layout=True)
fig.suptitle('Next Word Prediction — Training History\n(Stacked Bi-LSTM + Multi-Head Attention)',
             fontsize=14, fontweight='bold', y=1.01)
gs = gridspec.GridSpec(2, 2, figure=fig, hspace=0.35, wspace=0.3)

# Panel 1: Loss curves
ax1 = fig.add_subplot(gs[0, 0])
ax1.plot(epochs_ran, hist['loss'],     color=PALETTE['train'], lw=2, label='Training loss')
ax1.plot(epochs_ran, hist['val_loss'], color=PALETTE['val'],   lw=2, label='Validation loss', linestyle='--')
ax1.axvline(x=hist['val_loss'].index(min(hist['val_loss']))+1,
            color='gray', lw=1, linestyle=':', label='Best epoch')
ax1.set_title('Cross-Entropy Loss', fontweight='bold')
ax1.set_xlabel('Epoch'); ax1.set_ylabel('Loss')
ax1.legend(fontsize=9); ax1.xaxis.set_major_locator(MaxNLocator(integer=True))

# Panel 2: Accuracy curves
ax2 = fig.add_subplot(gs[0, 1])
ax2.plot(epochs_ran, hist['accuracy'],     color=PALETTE['train'], lw=2, label='Training acc')
ax2.plot(epochs_ran, hist['val_accuracy'], color=PALETTE['val'],   lw=2, label='Validation acc', linestyle='--')
ax2.set_title('Top-1 Accuracy', fontweight='bold')
ax2.set_xlabel('Epoch'); ax2.set_ylabel('Accuracy')
ax2.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: f'{y:.0%}'))
ax2.legend(fontsize=9)

# Panel 3: Perplexity curves
ax3 = fig.add_subplot(gs[1, 0])
ax3.plot(epochs_ran, hist['perplexity'],     color=PALETTE['train'], lw=2, label='Training PPL')
ax3.plot(epochs_ran, hist['val_perplexity'], color=PALETTE['val'],   lw=2, label='Validation PPL', linestyle='--')
ax3.set_title('Perplexity (lower = better)', fontweight='bold')
ax3.set_xlabel('Epoch'); ax3.set_ylabel('Perplexity')
ax3.legend(fontsize=9)
ax3.set_yscale('log')

# Panel 4: Learning Rate schedule
ax4 = fig.add_subplot(gs[1, 1])
lr_history = hist.get('lr', [LEARNING_RATE] * len(epochs_ran))
ax4.step(list(epochs_ran), lr_history, color='#3B8BD4', lw=2, where='post', label='Learning rate')
ax4.set_title('Learning Rate Schedule', fontweight='bold')
ax4.set_xlabel('Epoch'); ax4.set_ylabel('Learning Rate')
ax4.set_yscale('log')
ax4.legend(fontsize=9)

plt.savefig('training_curves.png', dpi=150, bbox_inches='tight')
plt.show()
print('Training curves saved to training_curves.png')
# Out:
# Training ran for 26 epochs
# Best val_loss: 5.0565 at epoch 11
# Best val_accuracy: 21.10%
# Training curves saved to training_curves.png

# %% [markdown]
# ---
# ## Cell 9 — Test Set Evaluation

# %%
# ─── Evaluate on the held-out TEST set ───────────────────────────────────────
# This cell is run separately as a standalone verification step
test_results = model.evaluate(
    X_test, y_test,
    batch_size=BATCH_SIZE,
    verbose=1
)
test_loss, test_acc, test_ppl = test_results[0], test_results[1], test_results[2]

# ─── Top-5 accuracy (compute from raw predictions) ───────────────────────────
y_pred_probs = model.predict(X_test, batch_size=BATCH_SIZE, verbose=0)
top5_acc = top_k_accuracy_score(y_test_int, y_pred_probs, k=5, labels=np.arange(VOCAB_SIZE))

print('\n' + '═'*58)
print('  TEST SET RESULTS')
print('═'*58)
print(f'  Test Loss (CE)      : {test_loss:>7.4f}')
print(f'  Test Accuracy       : {test_acc*100:>6.2f} %')
print(f'  Test Perplexity     : {test_ppl:>6.2f}')
print(f'  Top-5 Accuracy      : {top5_acc*100:>6.2f} %')
print('═'*58)
print(f'\nBaseline comparison:')
print(f'  Random baseline perplexity : {VOCAB_SIZE:,.1f}  (vocab size)')
print(f'  Model perplexity           : {test_ppl:.2f}   → {VOCAB_SIZE/test_ppl:.0f}x better than random')
most_common_acc = max(tokenizer.word_counts.values()) / TOTAL_WORDS
print(f'  Most-frequent-word baseline accuracy : ~{most_common_acc*100:.1f}%')
print(f'  Model accuracy                       : {test_acc*100:.1f}%')
# Out:
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.1861 - loss: 5.1327 - perplexity: 157.6523
#
# ══════════════════════════════════════════════════════════
#   TEST SET RESULTS
# ══════════════════════════════════════════════════════════
#   Test Loss (CE)      :  5.1327
#   Test Accuracy       :  18.61 %
#   Test Perplexity     : 157.65
#   Top-5 Accuracy      :  38.93 %
# ══════════════════════════════════════════════════════════
#
# Baseline comparison:
#   Random baseline perplexity : 5,000.0  (vocab size)
#   Model perplexity           : 157.65   → 32x better than random
#   Most-frequent-word baseline accuracy : ~7.9%
#   Model accuracy                       : 18.6%

# %% [markdown]
# ---
# ## Cell 10 — Text Generation

# %%
# ─── Text generation with temperature sampling ────────────────────────────────
def generate_text(
    model,
    tokenizer,
    seed_text: str,
    n_words: int = 10,
    temperature: float = 0.8,
    seq_len: int = SEQ_LEN
) -> str:
    """
    Generate text by repeatedly predicting the next word.
    
    Temperature scaling:
      - Low (0.3-0.5): picks high-probability words → focused, repetitive
      - Medium (0.7-1.0): balanced creativity vs coherence
      - High (1.2-1.5): more diverse/surprising outputs
    """
    generated = seed_text.lower().split()

    for _ in range(n_words):
        # Take the last seq_len words as the input window
        input_words = generated[-seq_len:]
        input_seq = tokenizer.texts_to_sequences([' '.join(input_words)])[0]

        # Pad if shorter than seq_len (beginning of text)
        input_seq = pad_sequences([input_seq], maxlen=seq_len, padding='pre')

        # Get raw probability distribution over vocabulary
        probs = model.predict(input_seq, verbose=0)[0]  # shape: (vocab_size,)

        # Temperature scaling: sharpen (T<1) or flatten (T>1) the distribution
        probs = np.log(probs + 1e-10) / temperature
        probs = np.exp(probs - np.max(probs))  # numerically stable softmax
        probs = probs / probs.sum()

        # Multinomial sampling from the scaled distribution
        next_word_id = np.random.choice(len(probs), p=probs)

        # Convert integer ID back to word string
        next_word = tokenizer.index_word.get(next_word_id, '<OOV>')
        generated.append(next_word)

    # Return only the generated portion (not the seed)
    return ' '.join(generated[len(seed_text.split()):])


# ─── Demo generation with multiple seeds and temperatures ─────────────────────
seeds = [
    'to be or not to be that is the question whether tis nobler',
    'all the world is a stage and all the men and women'
]
temperatures = [0.5, 0.8, 1.2]
temp_labels  = ['focused/conservative', 'balanced', 'creative/diverse']

print('═'*58)
print('  TEXT GENERATION DEMO')
print('═'*58)

for seed in seeds:
    print(f'\nSeed: \'{seed}\'')
    print()
    for temp, label in zip(temperatures, temp_labels):
        generated = generate_text(model, tokenizer, seed, n_words=10, temperature=temp)
        print(f'[Temperature={temp} — {label}]')
        print(f'  → \'{generated}\'')
        print()
    print('─'*58)
# Out:
# ══════════════════════════════════════════════════════════
#   TEXT GENERATION DEMO
# ══════════════════════════════════════════════════════════
#
# Seed: 'to be or not to be that is the question whether tis nobler'
#
# [Temperature=0.5 — focused/conservative]
#   → '. thus is the <OOV> , the <OOV> , and'
#
# [Temperature=0.8 — balanced]
#   → '<OOV> than long . i will not go and have'
#
# [Temperature=1.2 — creative/diverse]
#   → 'well . we ll put before a weak golden <OOV>'
#
# ──────────────────────────────────────────────────────────
#
# Seed: 'all the world is a stage and all the men and women'
#
# [Temperature=0.5 — focused/conservative]
#   → '. and , most gracious sir , the <OOV> of'
#
# [Temperature=0.8 — balanced]
#   → ', that <OOV> mad , our <OOV> and <OOV> ,'
#
# [Temperature=1.2 — creative/diverse]
#   → 'flies were backward hence to italy , to <OOV> his'
#
# ──────────────────────────────────────────────────────────

# %% [markdown]
# ---
# ## Cell 11 — Top-K Prediction Analysis

# %%
# Inspect top-K predictions for a given seed
def top_k_predictions(
    model,
    tokenizer,
    seed_text: str,
    true_next_word: str = None,
    k: int = 10
):
    """Display the top-k predicted next words with probabilities."""
    # Encode the seed text
    input_seq = tokenizer.texts_to_sequences([seed_text.lower()])[0]
    input_seq = pad_sequences([input_seq], maxlen=SEQ_LEN, padding='pre')

    # Get model predictions
    probs = model.predict(input_seq, verbose=0)[0]  # (vocab_size,)
    top_k_ids = np.argsort(probs)[::-1][:k]         # indices of top-k probabilities

    print(f'Seed: \'{seed_text}\'')
    if true_next_word:
        print(f'Actual next word: \'{true_next_word}\'')
    print(f'\nTop-{k} predictions:')

    for rank, word_id in enumerate(top_k_ids, 1):
        word = tokenizer.index_word.get(word_id, '<OOV>')
        prob = probs[word_id]
        correct_marker = '  ← ✓ CORRECT' if word == true_next_word else ''
        print(f'  Rank {rank:2d} | {word:<16} | prob = {prob:.4f}{correct_marker}')


# Run on the famous Hamlet quote
top_k_predictions(
    model, tokenizer,
    seed_text='to be or not to be that is the',
    true_next_word='question',
    k=10
)
# Out:
# Seed: 'to be or not to be that is the'
# Actual next word: 'question'
#
# Top-10 predictions:
#   Rank  1 | <OOV>            | prob = 0.1470
#   Rank  2 | king             | prob = 0.0220
#   Rank  3 | man              | prob = 0.0173
#   Rank  4 | world            | prob = 0.0118
#   Rank  5 | good             | prob = 0.0112
#   Rank  6 | time             | prob = 0.0111
#   Rank  7 | more             | prob = 0.0104
#   Rank  8 | other            | prob = 0.0098
#   Rank  9 | very             | prob = 0.0098
#   Rank 10 | duke             | prob = 0.0089

# %% [markdown]
# ---
# ## Cell 12 — Save Artefacts & Summary

# %%
# ─── Save the final (last epoch) model ───────────────────────────────────────
model.save('final_model.keras')

# ─── Save the tokenizer (required for inference) ──────────────────────────────
with open('tokenizer.pkl', 'wb') as f:
    pickle.dump(tokenizer, f)

# ─── Save a JSON summary of all results ───────────────────────────────────────
hist = history.history

results_summary = {
    'architecture': 'Stacked Bi-LSTM (128→64) + MultiHeadAttention + Dense',
    'corpus': 'Shakespeare (3 plays via NLTK Gutenberg)',
    'vocab_size': VOCAB_SIZE,
    'total_tokens': int(TOTAL_WORDS),
    'seq_len': SEQ_LEN,
    'total_params': model.count_params(),
    'hyperparameters': {
        'optimizer': 'Adam',
        'learning_rate': LEARNING_RATE,
        'batch_size': BATCH_SIZE,
        'epochs_run': len(hist['loss']),
        'label_smoothing': 0.0,
        'embed_dim': EMBED_DIM,
        'lstm_units': [LSTM1_UNITS*2, LSTM2_UNITS*2],
        'mha_heads': MHA_HEADS
    },
    'results': {
        'test_loss': round(test_loss, 4),
        'test_accuracy': round(float(test_acc), 4),
        'test_perplexity': round(float(test_ppl), 2),
        'top5_accuracy': round(float(top5_acc), 4),
        'train_accuracy_final': round(hist['accuracy'][-1], 4),
        'val_accuracy_best': round(max(hist['val_accuracy']), 4)
    }
}

with open('results_summary.json', 'w') as f:
    json.dump(results_summary, f, indent=2)

# ─── Print final summary ──────────────────────────────────────────────────────
print('── Saved artefacts ───────────────────────────────────────')
for fname, desc in [
    ('best_model.keras',    'Best model weights (val_loss)'),
    ('final_model.keras',   'Final model weights (last epoch)'),
    ('tokenizer.pkl',       'Fitted Keras Tokenizer object'),
    ('training_log.csv',    'Epoch-by-epoch training history'),
    ('training_curves.png', 'Loss / Accuracy / Perplexity plots'),
    ('results_summary.json','All metrics as JSON'),
]:
    print(f'  {fname:<28} — {desc}')

print()
print('── Final Results Summary ─────────────────────────────────')
print(f'  Architecture : 2x Bi-LSTM (128→64) + MHA(4 heads) + Dense')
print(f'  Parameters   : {model.count_params():,} trainable')
print(f'  Corpus       : Shakespeare (3 plays, ~67K tokens, vocab {VOCAB_SIZE:,})')
print()
print(f'  Train accuracy   : {hist["accuracy"][-1]*100:.2f}%    Train loss   : {hist["loss"][-1]:.3f}')
print(f'  Val accuracy     : {hist["val_accuracy"][-1]*100:.2f}%    Val loss     : {hist["val_loss"][-1]:.3f}')
print(f'  TEST accuracy    : {test_acc*100:.2f}%    Test loss    : {test_loss:.3f}')
print(f'  Test perplexity  : {test_ppl:.2f}      Top-5 acc    : {top5_acc*100:.2f}%')
print()
print(f'  Random baseline perplexity : {VOCAB_SIZE:,}')
print(f'  Improvement over random    : {VOCAB_SIZE/test_ppl:.0f}×')
# Out:
# ── Saved artefacts ───────────────────────────────────────
#   best_model.keras             — Best model weights (val_loss)
#   final_model.keras            — Final model weights (last epoch)
#   tokenizer.pkl                — Fitted Keras Tokenizer object
#   training_log.csv             — Epoch-by-epoch training history
#   training_curves.png          — Loss / Accuracy / Perplexity plots
#   results_summary.json         — All metrics as JSON
#
# ── Final Results Summary ─────────────────────────────────
#   Architecture : 2x Bi-LSTM (128→64) + MHA(4 heads) + Dense
#   Parameters   : 2,452,872 trainable
#   Corpus       : Shakespeare (3 plays, ~67K tokens, vocab 5,000)
#
#   Train accuracy   : 23.84%    Train loss   : 4.156
#   Val accuracy     : 21.10%    Val loss     : 5.126
#   TEST accuracy    : 18.61%    Test loss    : 5.133
#   Test perplexity  : 157.65      Top-5 acc    : 38.93%
#
#   Random baseline perplexity : 5,000
#   Improvement over random    : 32×
